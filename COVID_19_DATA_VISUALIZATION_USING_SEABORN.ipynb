# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishankumar1328/-DATA-ANALYSICS/blob/main/COVID_19_DATA_VISUALIZATION_USING_SEABORN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_csv("/content/owid-covid-data.csv")
df
# Out:
#       iso_code      continent       location        date  total_cases  \
# 0          ABW  North America          Aruba  2020-03-13          2.0
# 1          ABW  North America          Aruba  2020-03-19          NaN
# 2          ABW  North America          Aruba  2020-03-20          4.0
# 3          ABW  North America          Aruba  2020-03-21          NaN
# 4          ABW  North America          Aruba  2020-03-22          NaN
# ...        ...            ...            ...         ...          ...
# 52868      NaN            NaN  International  2020-10-23        696.0
# 52869      NaN            NaN  International  2020-10-24        696.0
# 52870      NaN            NaN  International  2020-10-25        696.0
# 52871      NaN            NaN  International  2020-10-26        696.0
# 52872      NaN            NaN  International  2020-10-27        696.0
#
#        new_cases  new_cases_smoothed  total_deaths  new_deaths  \
# ...

# %%
df.loc[:,["total_cases","total_deaths"]]
# Out:
#       total_cases  total_deaths
# 0             2.0           NaN
# 1             NaN           NaN
# 2             4.0           NaN
# 3             NaN           NaN
# 4             NaN           NaN
# ...           ...           ...
# 9583         99.0           2.0
# 9584         99.0           2.0
# 9585        142.0           2.0
# 9586        193.0           6.0
# 9587        233.0           6.0
#
# [9588 rows x 2 columns]

# %%
df.loc[df['location'].isin(['Aruba', 'Afghanistan'])]
# Out:
#     iso_code      continent     location        date  total_cases  new_cases  \
# 0        ABW  North America        Aruba  2020-03-13          2.0        2.0
# 1        ABW  North America        Aruba  2020-03-19          NaN        NaN
# 2        ABW  North America        Aruba  2020-03-20          4.0        2.0
# 3        ABW  North America        Aruba  2020-03-21          NaN        NaN
# 4        ABW  North America        Aruba  2020-03-22          NaN        NaN
# ..       ...            ...          ...         ...          ...        ...
# 521      AFG           Asia  Afghanistan  2020-10-23      40626.0      116.0
# 522      AFG           Asia  Afghanistan  2020-10-24      40687.0       61.0
# 523      AFG           Asia  Afghanistan  2020-10-25      40768.0       81.0
# 524      AFG           Asia  Afghanistan  2020-10-26      40833.0       65.0
# 525      AFG           Asia  Afghanistan  2020-10-27      41032.0      199.0
#
# ...

# %%
df[["continent","date","total_cases","new_cases","total_deaths","new_deaths"]]
# Out:
#            continent        date  total_cases  new_cases  total_deaths  \
# 0      North America  2020-03-13          2.0        2.0           NaN
# 1      North America  2020-03-19          NaN        NaN           NaN
# 2      North America  2020-03-20          4.0        2.0           NaN
# 3      North America  2020-03-21          NaN        NaN           NaN
# 4      North America  2020-03-22          NaN        NaN           NaN
# ...              ...         ...          ...        ...           ...
# 14188  South America  2020-07-29      82279.0     1118.0        5584.0
# 14189  South America  2020-07-30      83193.0      914.0        5623.0
# 14190  South America  2020-07-31      84370.0     1177.0        5657.0
# 14191  South America  2020-08-01      85355.0      985.0        5702.0
# 14192  South America  2020-08-02      86232.0      877.0        5736.0
#
#        new_deaths
# 0             0.0
# 1             NaN
# 2             0.0
# 3             NaN
# ...

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
x=df["continent"]
y=df["total_deaths"]

# %%
sns.barplot(x=x,y=y)
# Out:
# <Axes: xlabel='continent', ylabel='total_deaths'>

# %%
sns.barplot(x=x1,y=y1)
# Out:
# <Axes: xlabel='continent', ylabel='total_deaths'>

# %%
x=df["continent"]
y=df["total_cases"]
x1=df["continent"]
y1=df["total_deaths"]
sns.lineplot(x=x1,y=y1,color="hotpink")
sns.lineplot(x=x,y=y,color="yellowgreen")
# Out:
# <Axes: xlabel='continent', ylabel='total_deaths'>

# %%
sns.violinplot(x=x,y=y)
# Out:
# <Axes: xlabel='continent', ylabel='total_cases'>

# %%
sns.regplot(x=y,y=y1,data=df)
# Out:
# <Axes: xlabel='total_cases', ylabel='total_deaths'>

# %%
sns.scatterplot(x=x,y=y)
# Out:
# <Axes: xlabel='continent', ylabel='total_cases'>

# %%
sns.scatterplot(x=x1,y=y1)
# Out:
# <Axes: xlabel='continent', ylabel='total_deaths'>

# %%
numeric_columns = df.select_dtypes(include=['number'])

sns.heatmap(numeric_columns.corr(), annot=True, fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
sns.boxplot(x=x,y=y)
# Out:
# <Axes: xlabel='continent', ylabel='total_cases'>

# %%
sns.boxplot(x=x1,y=y1)
# Out:
# <Axes: xlabel='continent', ylabel='total_deaths'>

# %%
x1=df["continent"].tail(2000)
y1=df["total_deaths"].tail(2000)
sns.swarmplot(x=x1,y=y1)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 87.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 84.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 71.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='continent', ylabel='total_deaths'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 92.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...

# %%
x=df["continent"].tail(2000)
y=df["total_cases"].tail(2000)
sns.swarmplot(x=x,y=y,data=df)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 96.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 85.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 72.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='continent', ylabel='total_cases'>
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 97.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# ...
