# %% [markdown]
# <a href="https://colab.research.google.com/github/Kishankumar1328/-DATA-ANALYSICS/blob/main/vizualization_and_predict_the_cost_of_tomatoes.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
from sklearn.linear_model import LinearRegression

# %%
df=pd.read_csv("/content/tomato dataset.csv")
df
# Out:
#             Date Unit  Minimum  Maximum  Average  Market
# 0     16-06-2013   Kg       26       32     29.0  Tomato
# 1     17-06-2013   Kg       20       25     22.5  Tomato
# 2     18-06-2013   Kg       22       26     24.0  Tomato
# 3     19-06-2013   Kg       24       28     26.0  Tomato
# 4     20-06-2013   Kg       22       26     24.0  Tomato
# ...          ...  ...      ...      ...      ...     ...
# 2736  09-05-2021   Kg       10       15     12.5  Tomato
# 2737  10-05-2021   Kg       10       15     12.5  Tomato
# 2738  11-05-2021   Kg       10       15     12.5  Tomato
# 2739  12-05-2021   Kg       30       35     32.5  Tomato
# 2740  13-05-2021   Kg       35       40     37.5  Tomato
#
# [2741 rows x 6 columns]

# %%
df.shape
# Out:
# (2741, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2741 entries, 0 to 2740
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     2741 non-null   object
#  1   Unit     2741 non-null   object
#  2   Minimum  2741 non-null   int64
#  3   Maximum  2741 non-null   int64
#  4   Average  2741 non-null   float64
#  5   Market   2741 non-null   object
# dtypes: float64(1), int64(2), object(3)
# memory usage: 128.6+ KB

# %%
df.isnull()
# Out:
#        Date   Unit  Minimum  Maximum  Average  Market
# 0     False  False    False    False    False   False
# 1     False  False    False    False    False   False
# 2     False  False    False    False    False   False
# 3     False  False    False    False    False   False
# 4     False  False    False    False    False   False
# ...     ...    ...      ...      ...      ...     ...
# 2736  False  False    False    False    False   False
# 2737  False  False    False    False    False   False
# 2738  False  False    False    False    False   False
# 2739  False  False    False    False    False   False
# 2740  False  False    False    False    False   False
#
# [2741 rows x 6 columns]

# %%
df[["Date","Minimum","Maximum","Average"]]
# Out:
#             Date  Minimum  Maximum  Average
# 0     16-06-2013       26       32     29.0
# 1     17-06-2013       20       25     22.5
# 2     18-06-2013       22       26     24.0
# 3     19-06-2013       24       28     26.0
# 4     20-06-2013       22       26     24.0
# ...          ...      ...      ...      ...
# 2736  09-05-2021       10       15     12.5
# 2737  10-05-2021       10       15     12.5
# 2738  11-05-2021       10       15     12.5
# 2739  12-05-2021       30       35     32.5
# 2740  13-05-2021       35       40     37.5
#
# [2741 rows x 4 columns]

# %%
df["Average"].max()
# Out:
# 117.5

# %%
df["Average"].min()
# Out:
# 10.0

# %%
df["Average"].mode()
# Out:
# 0    32.5
# Name: Average, dtype: float64

# %%
df.describe()
# Out:
#            Minimum      Maximum      Average
# count  2741.000000  2741.000000  2741.000000
# mean     35.089748    41.281284    38.185516
# std      16.648425    17.364135    16.970949
# min       8.000000    12.000000    10.000000
# 25%      22.000000    30.000000    25.000000
# 50%      30.000000    38.000000    35.000000
# 75%      45.000000    50.000000    47.500000
# max     115.000000   120.000000   117.500000

# %%
plt.plot(df["Date"],df["Average"])

# %%
x=df["Date"].tail(29)
y=df["Maximum"].tail(29)
plt.barh(x,y)
# Out:
# <BarContainer object of 29 artists>

# %%
x=df["Minimum"]
plt.boxplot(x)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7eb5074a2ef0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7eb5074a2b60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7eb5074a0940>],
#  'medians': [<matplotlib.lines.Line2D at 0x7eb5074a3550>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7eb5074a0a00>],
#  'means': []}

# %%
y=df["Maximum"]
plt.boxplot(y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7eb506d76800>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7eb506d74970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7eb506d741f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7eb506d75e40>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7eb506d755a0>],
#  'means': []}

# %%
z=df["Average"]
plt.boxplot(z)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7eb507e0dab0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7eb507e0e410>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7eb507e0c310>],
#  'medians': [<matplotlib.lines.Line2D at 0x7eb507e0f010>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7eb507e0eaa0>],
#  'means': []}

# %%
x=df["Date"].tail(7)
y=df["Minimum"].tail(7)
x1=df["Date"].tail(7)
y1=df["Maximum"].tail(7)
plt.plot(x,y,color="hotpink",alpha=1)
plt.scatter(x,y,color="hotpink",alpha=1)
plt.plot(x1,y1,color="yellowgreen",alpha=1)
plt.scatter(x1,y1,color="yellowgreen",alpha=1)
plt.tight_layout()

# %%
x=df["Date"].tail(7)
y=df["Minimum"].tail(7)
plt.bar(x,y,color="hotpink",alpha=1)
plt.tight_layout()

# %%
x=df["Date"]
y=df["Maximum"]
sns.violinplot(x=x,y=y)
# Out:
# <Axes: xlabel='Date', ylabel='Maximum'>

# %%
x=df["Date"]
y=df["Maximum"]
sns.barplot(x=x,y=y)
# Out:
# <Axes: xlabel='Date', ylabel='Maximum'>

# %%
x=df["Date"].tail(5)
y=df["Maximum"].tail(5)
sns.scatterplot(x=x,y=y,color="pink")
sns.lineplot(x=x,y=y,color="pink")
plt.tight_layout()

# %%
x=df["Date"].tail(5)
y=df["Maximum"].tail(5)
sns.relplot(x=x,y=y)
plt.tight_layout()

# %%
x = df.tail(5)[["Minimum", "Maximum"]]
sns.pairplot(data=x)
plt.tight_layout()
plt.show()

# %%
x=df["Date"].tail(5)
y=df["Maximum"].tail(5)
sns.jointplot(x=x,y=y)
plt.tight_layout()

# %%
x=df["Date"].tail(5)
y=df["Maximum"].tail(5)
sns.stripplot(x=x,y=y)
plt.tight_layout()

# %%
x = df["Maximum"].tail(5)
sns.kdeplot(x)
plt.tight_layout()

# %%
sns.violinplot(x=x,y=y,df=df)
# Out:
# <Axes: xlabel='Maximum', ylabel='Maximum'>

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <ipython-input-5-8df7bcac526d>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(),annot=True)
# <Axes: >

# %%
sns.histplot(x=df["Maximum"],kde=True,data=df)
# Out:
# <Axes: xlabel='Maximum', ylabel='Count'>

# %%
sns.histplot(x=df["Minimum"],kde=True,data=df)
# Out:
# <Axes: xlabel='Minimum', ylabel='Count'>

# %%
sns.histplot(x=df["Average"],kde=True,data=df)
# Out:
# <Axes: xlabel='Average', ylabel='Count'>

# %%
# Out:
# <Axes: xlabel='Date', ylabel='Average'>

# %%
sns.boxplot(x=df["Average"])
# Out:
# <Axes: xlabel='Average'>

# %%
sns.boxplot(x=df["Minimum"])
# Out:
# <Axes: xlabel='Minimum'>

# %%
sns.boxplot(x=df["Maximum"])
# Out:
# <Axes: xlabel='Maximum'>

# %%
lm=LinearRegression()
x=df[["Minimum"]]
y=df["Average"]

# %%
lm.fit(x,y)
# Out:
# LinearRegression()

# %%
T=lm.predict(x)
print(T)
# Out:
# [28.93975379 22.83677128 24.87109878 ... 12.66513376 33.00840879
#  38.09422755]

# %%
k=lm.intercept_
print(k)
# Out:
# 2.493496248521758

# %%
kk=lm.coef_
print(kk)
# Out:
# [1.01716375]

# %%
price=k+kk*x

# %%
print(price)
# Out:
#         Minimum
# 0     28.939754
# 1     22.836771
# 2     24.871099
# 3     26.905426
# 4     24.871099
# ...         ...
# 2736  12.665134
# 2737  12.665134
# 2738  12.665134
# 2739  33.008409
# 2740  38.094228
#
# [2741 rows x 1 columns]
